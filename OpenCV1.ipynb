# %% [markdown]
# <a href="https://colab.research.google.com/github/SalehMehrabani/Deep-Learning/blob/main/OpenCV1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #OpenCv Introduction

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %%
print(cv2.__version__)
# Out:
# 4.6.0

# %%
# Ethereum Image
# https://drive.google.com/file/d/137QlIf7YI_ZluM2XcMEG7RBP7yxrf2hn/view?usp=sharing
# !gdown --id 137QlIf7YI_ZluM2XcMEG7RBP7yxrf2hn
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=137QlIf7YI_ZluM2XcMEG7RBP7yxrf2hn
# To: /content/Ethereum.png
# 100% 27.7k/27.7k [00:00<00:00, 67.9MB/s]

# %% [markdown]
# ##Reading Image

# %%
img= cv2.imread("/content/Ethereum.png")

# %%
plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
plt.axis(False)
plt.show()

# %% [markdown]
# ##BGR to RGB

# %%
def imshow_RGB(title: str = "Image" , image=None):
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.axis(False)
  plt.show()

# %%
#Imshow_BGR
plt.imshow(img)
plt.axis(False)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Imshow_RGB
imshow_RGB(title= "Ethereum", image= img)

# %% [markdown]
# ##Writing Image

# %%
cv2.imwrite("output.png", img)
# Out:
# True

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
# New York Times Square
# https://drive.google.com/file/d/1Cit2qPyfzNjPxcFj0PTrlcMTftPwgglp/view?usp=sharing
# !gdown --id 1Cit2qPyfzNjPxcFj0PTrlcMTftPwgglp
# Out:
# /usr/local/lib/python3.8/dist-packages/gdown/cli.py:127: FutureWarning: Option `--id` was deprecated in version 4.3.1 and will be removed in 5.0. You don't need to pass it anymore to use a file ID.
#   warnings.warn(
# Downloading...
# From: https://drive.google.com/uc?id=1Cit2qPyfzNjPxcFj0PTrlcMTftPwgglp
# To: /content/NewyorkTimesSquare.jpg
# 100% 312k/312k [00:00<00:00, 121MB/s]

# %%
def imshow(title= "Image", image= None, size=10):
  w, h= image.shape[0], image.shape[1]
  aspect_ratio= w/h
  plt.figure(figsize=(size*aspect_ratio, size))
  plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
  plt.title(title)
  plt.axis(False)
  plt.show()

# %%
img= cv2.imread("/content/NewyorkTimesSquare.jpg")
imshow(title= "New York Times Square", image=img, size= 5)

# %% [markdown]
# ##Gray Scalling Image

# %%
gray_img= cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
imshow(title= "New York Times Square", image=gray_img, size= 5)

# %%
img.shape
# Out:
# (900, 1200, 3)

# %% [markdown]
# ##Split Color Channels

# %%
b,g,r= cv2.split(img)
b.shape, g.shape, r.shape
# Out:
# ((900, 1200), (900, 1200), (900, 1200))

# %%
zeros= np.zeros(img.shape[:2], dtype="uint8")

# %%
imshow("Red", cv2.merge([zeros, zeros, r]))
imshow("Blue", cv2.merge([b, zeros, zeros]))
imshow("Green", cv2.merge([zeros, g, zeros]))

# %% [markdown]
# ### BGR to HSV
# * Hue: 0-179
# * Saturation: 0-255
# * Value(Intensity): 0-255

# %%
hsv_img= cv2.cvtColor(img, cv2.COLOR_BGR2HSV)
# hsv_img= cv2.cvtColor(img, cv2.COLOR_HSV2BGR)
imshow("hsv imag", hsv_img)

# %% [markdown]
# ##Drawing an Image

# %%
img= np.zeros(shape=(512,512,3), dtype=np.uint8)
gray_img= np.zeros(shape=(512,512), dtype= np.uint8)

imshow("black img - RGB", img)
imshow("gray img - GrayScale", gray_img)

# %%
cv2.line(img, (0,0), (511,511), (255, 127, 0), 5)
imshow("black with blue line - RGB", img)

# %%
# cv2.rectangle(image= img, 
#               starting_vertex=(100,100), 
#               opposite_vertex=(300,250), 
#               color=(127, 50, 127), 
#               thickness= 10)
cv2.rectangle(img,(100,100),(300,250),(127, 50, 127), 5)
imshow("image", img)

# %%
#image, center, radius, color, fill
cv2.circle(img,(447,63), 63, (0,0,255), -1)
imshow("image", img)

# %%
pts = np.array([[10,50],[400, 50],[90,200],[50,500]], np.int32)
pts = pts.reshape((-1,1,2))
cv2.polylines(img,[pts],True,(0,255,255))
imshow("image", img)

# %% [markdown]
# ##Put Text

# %%
img= np.zeros([1000,1000,3], np.uint8)
string="Pytorch"
cv2.putText(img, string, (155,290), cv2.FONT_HERSHEY_SCRIPT_SIMPLEX,3, (40,200,0), 4)
imshow("image", img)
